# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
import copy

# %% [markdown]
# ## Linear regression
#
# $\mathcal X=\mathbb R^d$, $\mathcal Y=\mathbb R$,
# $$ \|w\|_1:=\sum_{i=1}^d |w_i|,\quad \|w\|_2:=\sqrt{\sum_{i=1}^d |w_i|^2},$$
# $$\mathcal H=\{x\mapsto h(x)=\langle w,x\rangle+b\},$$
# + Ordinary linear regression
# $$ L_S(h)=\frac{1}{m}\sum_{i=1}^m(\langle w,x_i\rangle+b-y_i)^2\to\min_{w,b}$$
# + Ridge regression
# $$ L_S(h)+\lambda\|w\|_2^2\to\min_{w,b}$$
# + Lasso
# $$ L_S(h)+\lambda\|w\|_1\to\min_{w,b}$$
# + Elastic net
# $$ L_S(h)+\lambda_1\|w\|_2^2+\lambda_2\|w\|_1\to\min_{w,b}$$

# %% [markdown]
# Assume that samples correspond to the values of a 3rd order polynomial perturbed by a Gaussian noise:
# $$ y_i=x_i^3-5 x_i^2+3 x_i+1+\xi_i,\quad \xi_i\sim N(0,1),\quad x_i\sim U(-1,5)$$
# $i\in\{1,\dots,m\}$, $m=30$.

# %% [markdown]
# **1. Plot the graph of the unperturbed function and the scatter plot of $(x_i,y_i)$.**

# %%
np.random.seed(42)
m = 30
x = np.linspace(-1, 4, m)
y_real = x**3 - 5*x**2 + 3*x + 1

xi = np.random.normal(0,1,size=m)
y = x**3 - 5*x**2 + 3*x + 1 + xi

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(x, y_real, 'r', label="y_real")
ax.scatter(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Ordinary linear regression
# Consider an extended set of features: $\mathbf{x}=(x,x^2,\dots,x^d)$ (`PolynomialFeatures`) and the correspondent linear regression problem:
# $$ L_S(h)=\frac{1}{m}\sum_{i=1}^m(\langle\mathbf{w},\mathbf{x}_i\rangle+b-y_i)^2\to\min_{\mathbf{w},b}$$
# The hypothesis class
# $$\mathcal H_d=\{\mathbf{x}\mapsto h(\mathbf{x})=\langle\mathbf{w},\mathbf{x}\rangle+b\},$$
# depends on the hyperparameter $d$. Consider the training errors
# $$ \psi(d)=\inf_{\mathbf{w},b} L_S(h)$$
# and average cross-validation errors
# $$ \overline\psi(d)=\frac{1}{k}\sum_{i=1}^k\psi_i(d),\quad \psi_i(d)=\inf_{\mathbf{w},b} L_{S\backslash S_i}(h)$$
# for different values of $d$. Here $(S_1,\dots,S_d)$ is a partition of $S$, considered in the cross-validation.
#
# **2. Find $d$ with the best average cross-validation score.**

# %%
d = []
for i in range (1,11):
    d.append(i)
    
arr_err = []
arr_err_train = []

for i in range(1,11):
    x_new = copy.deepcopy(x)
    x_new = x_new.reshape(-1,1)
    poly = PolynomialFeatures(i, include_bias=False)
    new_p = poly.fit_transform(x_new)
    lr = LinearRegression()
    scores = cross_val_score(lr,new_p,y,cv=10)
    err = np.mean(-scores)
    
    lr = LinearRegression()
    err_train = lr.fit(new_p,y)
    err_train = err_train.score(new_p,y)
    
    arr_err.append(err)
    arr_err_train.append(err_train)    

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(d,arr_err, c='r')
ax.scatter(d,arr_err_train, c='b')
ax.legend(['Training errors','Average CV errors'])
ax.set_xlabel('polinomial degree')
ax.set_ylabel('errors')
print("Best score d = ",np.argmin(arr_err)+1)
# Out:
# Best score d =  3

# %% [markdown]
# **3. (a) Compute the training error of this predictor for the RMSE (root mean square error) evaluation metrics. Compare with the standard deviation of the data. (b) By the means of scatter plots compare the coefficients of the best predictor and the original coefficients.**

# %%
poly = PolynomialFeatures(3, include_bias = False)
p = poly.fit_transform(x_new)
reg = LinearRegression()
reg.fit(p, y)

rmse = mean_squared_error(reg.predict(p), y, squared=False)
print(rmse)

res3 = []
res3.extend([reg.intercept_])
res3.extend(reg.coef_)
print(res3)
true_coef = [1,3,-5,1]


fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter([i for i in range(4)],true_coef[::-1], c='g')
ax.scatter([i for i in range(4)],res3[::-1], c='b')
ax.legend(['True coef','Regression coef'])
# Out:
# 0.7936490700263198
# [1.1609138044827314, 2.4720321067943734, -4.947212869665639, 1.0154190835427395]

# %% [markdown]
# **4. Show the graphs of the predictors for d=3 and d=10 along with the unperturbed original function.**

# %%
poly = PolynomialFeatures(10, include_bias = False)
p10 = poly.fit_transform(x_new)
reg10 = LinearRegression()
reg10.fit(p10, y)

res10 = []
res10.extend([reg10.intercept_])
res10.extend(reg10.coef_)

print(res3)
print(res10)

y3 = np.polynomial.Polynomial(res3)
y10 = np.polynomial.Polynomial(res10)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x,y_real, 'r')
ax.plot(x,y3(x), 'b')
ax.plot(x,y10(x), 'orange')
ax.legend(['f','d=3','d=10'])
# Out:
# [1.1609138044827314, 2.4720321067943734, -4.947212869665639, 1.0154190835427395]
# [1.444726765235742, 2.6129941872564553, -3.974750102607603, 0.1347176389437505, -4.013554591624202, 3.233946649170749, 1.4624676447014004, -2.345511472418338, 0.9578543509492665, -0.16924653716587462, 0.01124121651241619]

# %% [markdown]
# ### Ridge regression
# Objective function in scikit-learn:
# $$ m\cdot L_S(h)+\alpha\|w\|_2^2$$
# **5. (a) Take a class polynomials, having a fixed large degree ($d=10$) and select the best regularization parameter $\alpha$. Compute the training error for the RMSE evaluation metrics for the best
# $\alpha$.**
#
# Consider log-scale for $\alpha$:
# `alphas=np.logspace(a_1,a_2,N=50,endpoint=True,b=10.0)`:
# $$ z_i=a_1+\frac{a_2-a_1}{N-1}i,\quad i=0,\dots,N-1,$$
# $$ \alpha_i=b^{z_i},\quad i=0,\dots,N-1.$$
# Note that the difference
# $$ \log_b \alpha_{i+1}-\log_b(\alpha_i)=z_{i+1}-z_i=\frac{a_2-a_1}{N-1}$$
# is constant.
#
# **5. (b) Show the dependence of the training and cross-validation errors on the regularization parameter**

# %%
alphas=np.logspace(0,3.61,50,endpoint=True)
param_grid = {'alpha' : alphas}
lr_reg = Ridge()
grid = GridSearchCV(estimator=lr_reg, param_grid=param_grid, scoring='neg_root_mean_squared_error', verbose=1, n_jobs=-1)
grid_result = grid.fit(p10, y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 235 out of 250 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:    0.0s finished

# %%
poly = PolynomialFeatures(10, include_bias = False)
p = poly.fit_transform(x_new)

alphas=np.logspace(0,2.5, 50,endpoint=True)

train_error = []
cv_error = []
for i in alphas:
    lr_reg = Ridge(alpha=i)
    lr_reg.fit(p, y)
    train_error.append(mean_squared_error(lr_reg.predict(p), y, squared=False))
    
    scores = cross_val_score(Ridge(alpha=i), p, y, cv=10 , scoring = 'neg_root_mean_squared_error')
    cv_error.append(-np.mean(scores))

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(alphas,train_error, c='y')
ax.scatter(alphas,cv_error, c='b')
ax.legend(['Training errors','CV errors'])
ax.set_xlabel('regularization parameter alpha')
ax.set_ylabel('errors')
print("Best regularization parameter: ", grid_result.best_estimator_.alpha)
print("RMSE for the best Ridge regression predictor: ", mean_squared_error(grid_result.predict(p), y, squared=False))
# Out:
# Best regularization parameter:  1.0
# RMSE for the best Ridge regression predictor:  0.8720270737241484

# %% [markdown]
# **6. Show the graphs of the best Ridge predictor along with the graph of the unperturbed original function.**

# %%
a = grid_result.best_estimator_.alpha
lr_reg = Ridge(alpha=a)
lr_reg.fit(p, y)
predict_alpha = lr_reg.predict(p)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x,y_real,'r')
ax.plot(x,predict_alpha)
s = 'alpha = '+str(a)
ax.legend(['f', s])

# %% [markdown]
# ### Lasso regression
# Objective function in scikit-learn:
# $$ \frac{1}{2}L_S(h)+\alpha\|w\|_1.$$
# **7. The problem is the same as 5, 6 for Ridge regression.**

# %%
alphas=np.logspace(0,3.61,50,endpoint=True)
param_grid = {'alpha' : alphas}
lr_reg = Lasso(max_iter=10000)
grid = GridSearchCV(estimator=lr_reg, param_grid=param_grid, scoring='neg_root_mean_squared_error', verbose=1, n_jobs=-1)
grid_result = grid.fit(p10, y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:    0.3s finished
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.26138524024182, tolerance: 0.038479245945909554
#   positive)

# %%
poly = PolynomialFeatures(10, include_bias = False)
p = poly.fit_transform(x_new)

alphas=np.logspace(0,1.5, 50,endpoint=True)

train_error = []
cv_error = []
for i in alphas:
    lr_reg = Lasso(alpha=i, max_iter=10000)
    lr_reg.fit(p, y)
    train_error.append(mean_squared_error(lr_reg.predict(p), y, squared=False))
    
    scores = cross_val_score(Lasso(alpha=i, max_iter=10000), p, y, cv=10 , scoring = 'neg_root_mean_squared_error')
    cv_error.append(-np.mean(scores))

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(alphas,train_error, c='y')
ax.scatter(alphas,cv_error, c='b')
ax.legend(['Training errors','CV errors'])
ax.set_xlabel('regularization parameter alpha')
ax.set_ylabel('errors')
print("Best regularization parameter: ", grid_result.best_estimator_.alpha)
print("RMSE for the best Lasso regression predictor: ", mean_squared_error(grid_result.predict(p), y, squared=False))
# Out:
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.698460864409036, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.607386464627847, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.56372371359028, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.072622368385765, tolerance: 0.027761670561482276
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.830919962576175, tolerance: 0.031765593820838024
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.21537541825789, tolerance: 0.03704033502753129
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.95242414552044, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.823995417764905, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.6918951861915, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.33819591533636, tolerance: 0.032154255934221214
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.63094784523031, tolerance: 0.037785248869391684
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.137522519203024, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.562468489629005, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.77133839980093, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.52118414019097, tolerance: 0.027761670561482276
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.003723577976935, tolerance: 0.031765593820838024
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.518020286437455, tolerance: 0.03704033502753129
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.21180542793735, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.071811505983284, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.98942338914215, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.36356008012832, tolerance: 0.032154255934221214
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.46980539086073, tolerance: 0.037785248869391684
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.1124255115559, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.09941037298708, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.561053441843214, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.63817711719404, tolerance: 0.027761670561482276
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.39205226593312, tolerance: 0.031765593820838024
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.36667173805748, tolerance: 0.03704033502753129
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.77553333136047, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.50062366683339, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.91789883236522, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.388989253564205, tolerance: 0.032154255934221214
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.94541970130368, tolerance: 0.037785248869391684
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.7806958601669, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.753710167037447, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.66204984640454, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.981359201085056, tolerance: 0.027761670561482276
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.546221056263676, tolerance: 0.031765593820838024
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.930459715981584, tolerance: 0.03704033502753129
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.41470055318659, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.565828597230066, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.352455351954795, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.833459473323515, tolerance: 0.032154255934221214
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.627085994513926, tolerance: 0.037785248869391684
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.70162866177547, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.078873025599485, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.89239846401419, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.71960965547587, tolerance: 0.027761670561482276
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.77169869639045, tolerance: 0.031765593820838024
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.24171955259889, tolerance: 0.03704033502753129
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.294596678500454, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60.07792501055824, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.71324903703108, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.82468730469389, tolerance: 0.032154255934221214
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.8032658442675, tolerance: 0.037785248869391684
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.854569885819174, tolerance: 0.038479245945909554
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.707016602056775, tolerance: 0.03646707199296109
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.76782400116276, tolerance: 0.034426439234914896
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.40935520680678, tolerance: 0.03830200946480901
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.71000834068104, tolerance: 0.035517450781613856
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.28985319500101, tolerance: 0.031170341245264764
#   positive)
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75.82182153263992, tolerance: 0.032154255934221214
#   positive)

# %%
a = grid_result.best_estimator_.alpha
lasso_reg = Lasso(alpha=a, max_iter=10000)
lasso_reg.fit(p, y)
predict_lasso = lasso_reg.predict(p)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x,y_real,'r')
ax.plot(x,predict_lasso)
s = 'alpha = '+str(a)
ax.legend(['f', s])
# Out:
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.26138524024182, tolerance: 0.038479245945909554
#   positive)

# %% [markdown]
# ## Elastic net
# Objective function in scikit-learn:
# $$ \frac{1}{2}L_S(h)+\alpha r \|\mathbf w\|_1+\frac{1}{2}\alpha(1-r)\|\mathbf{w}\|_2^2.$$
# **8. Fix some large $d$ and use `GridSearchCV` to find the best combination of $\alpha$ and $r$ (`l1_ratio`).**

# %%
alphas=np.logspace(0,3.61,50,endpoint=True)
s = np.linspace(0,1,11)
param_grid = {'alpha' : alphas, 
              'l1_ratio' : s }

lr_elastic = ElasticNet()
grid = GridSearchCV(estimator=lr_elastic, param_grid=param_grid, scoring='neg_root_mean_squared_error', verbose=1, n_jobs=-1)
grid_result = grid.fit(p, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 550 candidates, totalling 2750 fits
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 2672 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 2750 out of 2750 | elapsed:    1.3s finished
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.63909706392529, tolerance: 0.038479245945909554
#   positive)

# %%
print(grid_result.best_estimator_)
print("RMSE for the best papameters:", mean_squared_error(grid_result.predict(p), y, squared=False))
# Out:
# ElasticNet(alpha=2.7672017032884058, copy_X=True, fit_intercept=True,
#            l1_ratio=0.6000000000000001, max_iter=1000, normalize=False,
#            positive=False, precompute=False, random_state=None,
#            selection='cyclic', tol=0.0001, warm_start=False)
# RMSE for the best papameters: 2.0587576048881133

# %% [markdown]
# **9. Show the graphs of the best predictor along with the graph of the unperturbed original function.**

# %%
a = grid_result.best_estimator_.alpha
s = grid_result.best_estimator_.l1_ratio
lr_elastic = ElasticNet(alpha=a, l1_ratio=s)

lr_elastic.fit(p, y)
predict_elastic = lr_elastic.predict(p)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x,y_real,'r')
ax.plot(x,predict_elastic)
ax.legend(['f', 'Elastic net'])
# Out:
# C:\Users\gazan\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.63909706392529, tolerance: 0.038479245945909554
#   positive)

# %% [markdown]
# **10. Show the coefficients of the best Lasso and ElasticNet predictors**

# %%
res_lasso = []
res_lasso.extend([lasso_reg.intercept_])
res_lasso.extend(lasso_reg.coef_)

res_elastic = []
res_elastic.extend([lr_elastic.intercept_])
res_elastic.extend(lr_elastic.coef_)

print(res_lasso)
print(res_elastic)

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter([i for i in range(11)],res_elastic[::-1], c='b')
ax.scatter([i for i in range(11)],res_lasso[::-1], c='y')
ax.legend(['Elastic coef','Lasso coef'])
# Out:
# [-1.4645116444846757, -0.0, -0.0, -0.0, -0.0, -0.09713126955779264, -0.007872102568278309, 0.008172800360511455, 0.001637643038022843, -6.665721392127784e-05, -8.974569460617142e-05]
# [-1.2166369819729383, 0.0, -0.0, -0.0, -0.2678966983161492, 0.0022303152416777248, 0.01666904974841858, 0.0016283852059018756, 1.1734061021773231e-05, -4.50257784928701e-05, -1.870528496181813e-05]
